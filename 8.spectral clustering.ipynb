# %%
import pandas as pd
dataset=pd.read_csv("Mall_Customers.csv")
x=dataset.iloc[:,[3,4]].values

# %%
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#x_scaled = scaler.fit_transform(x)

# %%
from sklearn.cluster import SpectralClustering
cluster = SpectralClustering(n_clusters = 5, affinity ='nearest_neighbors')
y=cluster.fit_predict(x)
# Out:
# C:\Users\DELL\anaconda3\envs\aiml\lib\site-packages\sklearn\manifold\_spectral_embedding.py:261: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   "Graph is not fully connected, spectral embedding may not work as expected."

# %%
supervised=pd.DataFrame(dataset)
supervised['Cluster_group']=y
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster_group
# 0                3
# 1                0
# 2                3
# 3                0
# 4                3
# ..             ...
# 195              2
# 196              4
# 197              2
# 198              4
# 199              2
#
# [200 rows x 6 columns]

# %%
import seaborn as sns
facet=sns.lmplot(data=supervised,x=supervised.columns[3],y=supervised.columns[4],hue=supervised.columns[5],
                 fit_reg=False,legend_out=True,legend=True)
# Out:
# C:\Users\DELL\anaconda3\envs\aiml\lib\site-packages\seaborn\regression.py:582: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
